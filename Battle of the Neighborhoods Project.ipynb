# %% [markdown]
# ## Battle of the Neighborhoods Project

# %% [markdown]
# ### Introduction: Business Problem

# %% [markdown]
# In the project we are trying to find locations in the city of Los Angeles that would be optimal for opening a new Thai restaurant. We are trying to find locations that are <b>1) popular locations to eat out (ie. high density of restaurants)</b>, and <b>2) contain few to none other Thai restaurants in order to minimize competition</b>.

# %% [markdown]
# ### Data
