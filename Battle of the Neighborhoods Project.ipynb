# %% [markdown]
# ## Battle of the Neighborhoods Project

# %% [markdown]
# ### Introduction: Business Problem

# %% [markdown]
# In the project we are trying to find locations in the city of Los Angeles that would be optimal for opening a new Thai restaurant. We are trying to find locations that are <b>1) known and popular for their quality restaurants</b>, and <b>2) contain few to none other Thai restaurants in order to minimize competition</b>.
